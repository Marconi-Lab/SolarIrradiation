# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
directory = '/content/drive/MyDrive/Solar irradiance Data - 2018/Pipeline/CSVs'
files = [f for f in os.listdir(directory) if f.endswith('.csv')]
files.sort()
files
# Out:
# ['kampala_data (1).csv',
#  'kampala_data.csv',
#  'lira_data.csv',
#  'mbarara_data.csv',
#  'tororo_data.csv']

# %%
df_kampala = pd.read_csv(os.path.join(directory, files[0]), index_col='datetime', parse_dates=['datetime'])
df_lira = pd.read_csv(os.path.join(directory, files[1]), index_col='datetime', parse_dates=['datetime'])
df_mbarara = pd.read_csv(os.path.join(directory, files[2]), index_col='datetime', parse_dates=['datetime'])
df_tororo = pd.read_csv(os.path.join(directory, files[3]), index_col='datetime', parse_dates=['datetime'])

# %%
df_kampala.head()
# Out:
#                        SUN  BHI (W/m2)  GHI (W/m2)  GTI_30 (W/m2)  \
# datetime
# 2011-04-05 10:00:00  501.6      767.61    0.115833     223.297222
# 2011-04-05 11:00:00  663.2     2575.30    0.277778     751.138889
# 2011-04-05 12:00:00  648.1     3199.50    0.273056     930.277778
# 2011-04-05 13:00:00  318.5     2568.30    0.166667     739.388889
# 2011-04-05 14:00:00  240.7     1874.40    0.101944     535.777778
#
#                      GTI_15 (W/m2)  GTI_22.5 (W/m2)
# datetime
# 2011-04-05 10:00:00            0.0              0.0
# 2011-04-05 11:00:00            0.0              0.0
# 2011-04-05 12:00:00            0.0              0.0
# 2011-04-05 13:00:00            0.0              0.0
# 2011-04-05 14:00:00            0.0              0.0

# %%
df_kampala.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52456 entries, 2011-04-05 10:00:00 to 2023-02-01 09:00:00
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SUN              52456 non-null  float64
#  1   BHI (W/m2)       52456 non-null  float64
#  2   GHI (W/m2)       52456 non-null  float64
#  3   GTI_30 (W/m2)    52456 non-null  float64
#  4   GTI_15 (W/m2)    52456 non-null  float64
#  5   GTI_22.5 (W/m2)  52456 non-null  float64
# dtypes: float64(6)
# memory usage: 2.8 MB

# %% [markdown]
# ## Profile reports

# %%
# !pip install ydata-profiling --q
from ydata_profiling import ProfileReport
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 61.7 MB/s eta 0:00:00
#   Building wheel for htmlmin (setup.py) ... done

# %%
profile = ProfileReport(df_kampala, title="Kampala Report", tsmode=True)
profile.to_notebook_iframe()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
profile = ProfileReport(df_lira, title="Lira Report", tsmode=True)
profile.to_notebook_iframe()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
profile = ProfileReport(df_mbarara, title="Mbarara Report", tsmode=True)
profile.to_notebook_iframe()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
profile = ProfileReport(df_tororo, title="Tororo Report", tsmode=True)
profile.to_notebook_iframe()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
