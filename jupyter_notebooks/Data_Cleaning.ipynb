# %%
import pandas as pd
from susse.estimators.data.wrangling import wrangle_CAMSRAD_data, wrangle_Solcast_data, wrangle_NREL_Data

# %% [markdown]
# # CAMSRAD Data Processing

# %%
df = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Egypt/raw/CAMSRAD_location1.csv')

# %%
df.head()
# Out:
#    TAO (kWh/m2/day)  Clear sky GHI (kWh/m2/day)  Clear sky BHI (kWh/m2/day)  \
# 0          9.949236                    7.064093                    5.063737
# 1          9.909081                    7.397833                    6.086805
# 2          9.868389                    7.374729                    5.954697
# 3          9.827185                    7.328903                    5.809644
# 4          9.785438                    7.287530                    5.718695
#
#    Clear sky DHI (kWh/m2/day)  Clear sky DNI (kWh/m2/day)  GHI (kWh/m2/day)  \
# 0                    2.000355                    7.190065          7.064093
# 1                    1.311028                    8.844054          7.397833
# 2                    1.420032                    8.687866          7.129047
# 3                    1.519259                    8.539902          7.328903
# 4                    1.568834                    8.398243          7.287530
#
# ...

# %% [markdown]
# # NREL Data Processing

# %%
df = wrangle_Solcast_data('Data/irradiation_estimates/CBE_Data/Egypt/raw/Solcast_Location1_29.887561_32.460447_fixed_23_180_PT60M.csv')

# %%
df.head()
# Out:
#                            air_temp (°C)  clearsky_dhi (kWh/m2/day)  \
# period_end
# 2023-09-01 00:00:00+03:00      29.350000                      1.965
# 2023-09-02 00:00:00+03:00      28.458333                      1.625
# 2023-09-03 00:00:00+03:00      28.458333                      1.696
# 2023-09-04 00:00:00+03:00      28.791667                      2.006
# 2023-09-05 00:00:00+03:00      30.291667                      1.556
#
#                            clearsky_dni (kWh/m2/day)  \
# period_end
# 2023-09-01 00:00:00+03:00                      6.846
# 2023-09-02 00:00:00+03:00                      7.561
# 2023-09-03 00:00:00+03:00                      7.492
# 2023-09-04 00:00:00+03:00                      6.789
# 2023-09-05 00:00:00+03:00                      7.950
#
#                            clearsky_ghi (kWh/m2/day)  \
# period_end
# 2023-09-01 00:00:00+03:00                      6.790
# 2023-09-02 00:00:00+03:00                      6.995
# ...

# %% [markdown]
# # NREL Data Processing
