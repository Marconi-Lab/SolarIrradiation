# %%
from susse.estimators.data.wrangling import wrangle_CAMSRAD_data, wrangle_Solcast_data, wrangle_NREL_Data

# %% [markdown]
# # Soroti

# %%
camsrad1 = wrangle_CAMSRAD_data('Data/irradiation_estimates/ministry_energy_ug/raw_data/Soroti/Soroti_CAMS-RAD2020.csv')
camsrad2 = wrangle_CAMSRAD_data('Data/irradiation_estimates/ministry_energy_ug/raw_data/Soroti/Soroti_CAMS-RAD2021.csv')

camsrad1.to_csv('Data/irradiation_estimates/ministry_energy_ug/Soroti/Soroti_CAMSRAD2020.csv', index=False)
camsrad2.to_csv('Data/irradiation_estimates/ministry_energy_ug/Soroti/Soroti_CAMSRAD2021.csv', index=False)

# %%
nrel1 = wrangle_NREL_Data('Data/irradiation_estimates/ministry_energy_ug/raw_data/Soroti/Soroti_NREL2020.csv')
nrel2 = wrangle_NREL_Data('Data/irradiation_estimates/ministry_energy_ug/raw_data/Soroti/Soroti_NREL2021.csv')

nrel1.to_csv('Data/irradiation_estimates/ministry_energy_ug/Soroti/Soroti_nrel2020.csv', index=False)
nrel2.to_csv('Data/irradiation_estimates/ministry_energy_ug/Soroti/Soroti_nrel2021.csv', index=False)

# %% [markdown]
# # Wadelai

# %%
camsrad1 = wrangle_CAMSRAD_data('Data/irradiation_estimates/ministry_energy_ug/raw_data/Wadelai/Wadelai_CAMS-RAD2020.csv')
camsrad2 = wrangle_CAMSRAD_data('Data/irradiation_estimates/ministry_energy_ug/raw_data/Wadelai/Wadelai_CAMS-RAD2021.csv')

camsrad1.to_csv('Data/irradiation_estimates/ministry_energy_ug/Wadelai/Wadelai_CAMSRAD2020.csv', index=False)
camsrad2.to_csv('Data/irradiation_estimates/ministry_energy_ug/Wadelai/Wadelai_CAMSRAD2021.csv', index=False)

# %%
nrel1 = wrangle_NREL_Data('Data/irradiation_estimates/ministry_energy_ug/raw_data/Wadelai/Wadelai_NREL2020.csv')
nrel2 = wrangle_NREL_Data('Data/irradiation_estimates/ministry_energy_ug/raw_data/Wadelai/Wadelai_NREL2021.csv')

nrel1.to_csv('Data/irradiation_estimates/ministry_energy_ug/Wadelai/Wadelai_nrel2020.csv', index=False)
nrel2.to_csv('Data/irradiation_estimates/ministry_energy_ug/Wadelai/Wadelai_nrel2021.csv', index=False)

# %%
nrel1.head()
# Out:
#    index                Date  Solar Zenith Angle (Degrees)  Surface Albedo  \
# 0      0 2020-01-01 00:30:00                        158.63            0.17
# 1      1 2020-01-01 01:30:00                        158.29            0.17
# 2      2 2020-01-01 02:30:00                        149.86            0.17
# 3      3 2020-01-01 03:30:00                        137.89            0.16
# 4      4 2020-01-01 04:30:00                        124.79            0.16
#
#    Precipitable Water (cm)  Clearsky DHI (W/m2)  Clearsky DNI (W/m2)  \
# 0                      4.6                    0                    0
# 1                      4.5                    0                    0
# 2                      4.4                    0                    0
# 3                      3.0                    0                    0
# 4                      2.9                    0                    0
#
#    Clearsky GHI (W/m2)  Cloud Type  Dew Point (C)  Relative Humidity (%)  \
# ...

# %% [markdown]
# # Egypt

# %%
solcast = wrangle_Solcast_data('Data/irradiation_estimates/CBE_Data/Egypt/raw/Solcast_Location1_29.887561_32.460447_fixed_23_180_PT60M.csv')
solcast.to_csv('Data/irradiation_estimates/CBE_Data/Egypt/cleaned/Solcast_Location1_29.887561_32.460447_fixed_23_180_PT60M.csv', index=False)

# %%
camsrad = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Egypt/raw/CAMSRAD_location1.csv')
camsrad.to_csv('Data/irradiation_estimates/CBE_Data/Egypt/cleaned/CAMSRAD_location1.csv', index=False)

# %% [markdown]
# # Ghana

# %%
solcast1 = wrangle_Solcast_data('Data/irradiation_estimates/CBE_Data/Ghana/raw/Solcast_Location1_5.645759_-0.105223_fixed_23_180_PT60M.csv')
solcast2 = wrangle_Solcast_data('Data/irradiation_estimates/CBE_Data/Ghana/raw/Solcast_location2_5.645686_0.008678_fixed_23_180_PT60M.csv')
solcast3 = wrangle_Solcast_data('Data/irradiation_estimates/CBE_Data/Ghana/raw/Solcast_location3_5.632167_-0.235111_fixed_23_180_PT60M.csv')

# %%
solcast1.to_csv('Data/irradiation_estimates/CBE_Data/Ghana/cleaned/Solcast_Location1_5.645759_-0.105223_fixed_23_180_PT60M.csv', index=False)
solcast2.to_csv('Data/irradiation_estimates/CBE_Data/Ghana/cleaned/Solcast_location2_5.645686_0.008678_fixed_23_180_PT60M.csv', index=False)
solcast3.to_csv('Data/irradiation_estimates/CBE_Data/Ghana/cleaned/Solcast_location3_5.632167_-0.235111_fixed_23_180_PT60M.csv', index=False)

# %%
camsrad1 = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Ghana/raw/CAMSRAD_location1.csv')
camsrad2 = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Ghana/raw/CAMSRAD_location2.csv')
camsrad3 = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Ghana/raw/CAMSRAD_location3.csv')

# %%
camsrad1.to_csv('Data/irradiation_estimates/CBE_Data/Ghana/cleaned/CAMSRAD_location1.csv', index=False)
camsrad2.to_csv('Data/irradiation_estimates/CBE_Data/Ghana/cleaned/CAMSRAD_location2.csv', index=False)
camsrad3.to_csv('Data/irradiation_estimates/CBE_Data/Ghana/cleaned/CAMSRAD_location3.csv', index=False)

# %% [markdown]
# # Madagascar

# %%
solcast1 = wrangle_Solcast_data('Data/irradiation_estimates/CBE_Data/Madagascar/raw/Solcast_location1_-25.053564_46.947956_fixed_23_0_PT60M.csv')
solcast2 = wrangle_Solcast_data('Data/irradiation_estimates/CBE_Data/Madagascar/raw/Solcast_location2_-23.99_45.12_fixed_23_0_PT60M.csv')

# %%
solcast1.to_csv('Data/irradiation_estimates/CBE_Data/Madagascar/cleaned/Solcast_location1_-25.053564_46.947956_fixed_23_0_PT60M.csv', index=False)
solcast2.to_csv('Data/irradiation_estimates/CBE_Data/Madagascar/cleaned/Solcast_location2_-23.99_45.12_fixed_23_0_PT60M.csv', index=False)

# %%
camsrad1 = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Madagascar/raw/CAMSRAD_location1.csv')
camsrad2 = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Madagascar/raw/CAMSRAD_location2.csv')

# %%
camsrad1.to_csv('Data/irradiation_estimates/CBE_Data/Madagascar/cleaned/CAMSRAD_location1.csv', index=False)
camsrad2.to_csv('Data/irradiation_estimates/CBE_Data/Madagascar/cleaned/CAMSRAD_location2.csv', index=False)

# %% [markdown]
# # Nigeria

# %%
camsrad1 = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Nigeria/raw/CAMSRAD_location1.csv')
camsrad2 = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Nigeria/raw/CAMSRAD_location2.csv')
camsrad3 = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Nigeria/raw/CAMSRAD_location3.csv')

# %%
camsrad1.to_csv('Data/irradiation_estimates/CBE_Data/Nigeria/cleaned/CAMSRAD_location1.csv', index=False)
camsrad2.to_csv('Data/irradiation_estimates/CBE_Data/Nigeria/cleaned/CAMSRAD_location2.csv', index=False)
camsrad3.to_csv('Data/irradiation_estimates/CBE_Data/Nigeria/cleaned/CAMSRAD_location3.csv', index=False)

# %% [markdown]
# # Somalia

# %%
solcast1 = wrangle_Solcast_data('Data/irradiation_estimates/CBE_Data/Somalia/raw/Solcast_location1_3.107191_43.637153_fixed_23_180_PT60M.csv')
solcast1.to_csv('Data/irradiation_estimates/CBE_Data/Somalia/cleaned/Solcast_location1_3.107191_43.637153_fixed_23_180_PT60M.csv', index=False)

# %%
camsrad1 = wrangle_CAMSRAD_data('Data/irradiation_estimates/CBE_Data/Somalia/raw/CAMSRAD_location1.csv')
camsrad1.to_csv('Data/irradiation_estimates/CBE_Data/Somalia/cleaned/CAMSRAD_location1.csv', index=False)
