# %%
from numpy.ma.core import product
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../src")

# %%
from susse import NASAPowerFetchData, TemporalResolution, NASAPowerProduct
from datetime import datetime
from geopy.location import Location as GeopyLocation
from geopy import Point

start_date = datetime(2020, 1, 1)
end_date = datetime(2020, 12, 31)

location = Point(latitude=0.3152, longitude=32.5816)

# %%
products = list(NASAPowerProduct)
parameters = NASAPowerFetchData.fetch_multiple_parameters(start_date=start_date, end_date=end_date, location=location, products=products[:20])

# %%
parameters.to_dataframe()
# Out:
#              GHI   DHI   DNI  LONGWAVE_DOWNARD_IRR  TEMPERATURE  \
# timestamp
# 2020-01-01  6.90  1.61  7.52                  8.63        22.55
# 2020-01-02  6.76  1.80  7.19                  8.43        23.35
# 2020-01-03  6.41  3.09  5.84                  8.71        23.37
# 2020-01-04  5.95  2.84  4.55                  8.69        23.34
# 2020-01-05  5.41  2.42  3.78                  8.76        23.32
# ...          ...   ...   ...                   ...          ...
# 2020-12-27  5.45  2.85  3.20                  8.38        22.45
# 2020-12-28  6.92  2.05  6.87                  8.14        21.18
# 2020-12-29  6.87  1.61  7.51                  8.28        22.68
# 2020-12-30  5.88  2.42  5.02                  8.53        23.66
# 2020-12-31  2.86  2.05  0.48                  8.95        22.06
#
#             SPECIFIC_HUMIDITY  AEROSOL_OPTICAL_DEPTH_550nm  \
# timestamp
# 2020-01-01              13.79                         0.12
# 2020-01-02              14.06                         0.13
# 2020-01-03              14.16                         0.18
# 2020-01-04              14.90                         0.15
# 2020-01-05              14.82                         0.21
# ...                       ...                          ...
# 2020-12-27              13.26                         0.14
# 2020-12-28              11.89                         0.10
# 2020-12-29              13.02                         0.10
# 2020-12-30              13.61                         0.09
# 2020-12-31              14.79                         0.21
#
#             AEROSOL_OPTICAL_DEPTH_550nm_ADJ  RELATIVE_HUMIDITY  \
# timestamp
# 2020-01-01                             0.12              72.31
# 2020-01-02                             0.13              69.70
# 2020-01-03                             0.18              70.67
# 2020-01-04                             0.15              73.94
# 2020-01-05                             0.21              74.00
# ...                                     ...                ...
# 2020-12-27                             0.14              70.79
# 2020-12-28                             0.10              69.45
# 2020-12-29                             0.10              67.65
# 2020-12-30                             0.09              66.36
# 2020-12-31                             0.21              79.71
#
#             SURFACE_PRESSURE  AEROSOL_OPTICAL_DEPTH_840nm  \
# timestamp
# 2020-01-01             88.50                         0.08
# 2020-01-02             88.48                         0.09
# 2020-01-03             88.57                         0.12
# 2020-01-04             88.54                         0.10
# 2020-01-05             88.50                         0.15
# ...                      ...                          ...
# 2020-12-27             88.32                         0.10
# 2020-12-28             88.40                         0.07
# 2020-12-29             88.38                         0.07
# 2020-12-30             88.40                         0.08
# 2020-12-31             88.42                         0.18
#
#             CLOUD_VISIBLE_OPTICAL_DEPTH  CLOUD_AMOUNT_DAT  TOTAL_COLUMN_OZONE  \
# timestamp
# 2020-01-01                         1.70             30.09              242.54
# 2020-01-02                         2.65             26.22              243.14
# 2020-01-03                         1.08             77.22              242.23
# 2020-01-04                         2.43             77.34              235.23
# 2020-01-05                         4.56             71.27              243.44
# ...                                 ...               ...                 ...
# 2020-12-27                         1.84             73.10              250.22
# 2020-12-28                         2.36             33.74              246.76
# 2020-12-29                         3.05             20.24              245.09
# 2020-12-30                         1.74             68.87              244.97
# 2020-12-31                         8.09             98.64              246.31
#
#             SURFACE_ALBEDO  ALL_SKY_SURFACE_ALBEDO  CLEAR_SKY_ALBEDO  \
# timestamp
# 2020-01-01            0.16                    0.16              0.16
# 2020-01-02            0.16                    0.16              0.16
# 2020-01-03            0.16                    0.16              0.16
# 2020-01-04            0.16                    0.16              0.16
# 2020-01-05            0.15                    0.15              0.16
# ...                    ...                     ...               ...
# 2020-12-27            0.17                    0.17              0.17
# 2020-12-28            0.17                    0.17              0.17
# 2020-12-29            0.17                    0.17              0.17
# 2020-12-30            0.17                    0.17              0.17
# 2020-12-31            0.16                    0.16              0.17
#
#             PRECIPITABLE_WATER  SOLAR_ZENITH_ANGLE  CLEARNESS_INDEX
# timestamp
# 2020-01-01                2.79              -999.0             0.70
# 2020-01-02                2.58              -999.0             0.69
# 2020-01-03                3.01              -999.0             0.65
# 2020-01-04                3.12              -999.0             0.60
# 2020-01-05                3.27              -999.0             0.55
# ...                        ...                 ...              ...
# 2020-12-27                2.00              -999.0             0.56
# 2020-12-28                1.88              -999.0             0.70
# 2020-12-29                2.04              -999.0             0.70
# 2020-12-30                2.46              -999.0             0.60
# 2020-12-31                3.60              -999.0             0.29
#
# [366 rows x 20 columns]
