# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports
# Importing our susse library to test some of its functions

# %%
from susse.api_clients import ModisDataFetcher

# %% [markdown]
# # First tests

# %%
data_fetcher = ModisDataFetcher()
data_fetcher.surface_reflectance()
