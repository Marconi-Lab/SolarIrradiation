# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Out:
#                        SUN  BHI (W/m2)  GHI (W/m2)  GTI_30 (W/m2)  \
# datetime
# 2011-04-05 10:00:00  0.417       501.6  233.538889     213.225000
# 2011-04-05 11:00:00  1.000       663.2  785.388889     715.361111
# 2011-04-05 12:00:00  0.983       648.1  971.500000     888.750000
# 2011-04-05 13:00:00  0.600       318.5  776.583333     713.416667
# 2011-04-05 14:00:00  0.367       240.7  572.944444     520.666667
#
#                      GTI_15 (W/m2)  GTI_22.5 (W/m2)
# datetime
# 2011-04-05 10:00:00     223.297222              0.0
# 2011-04-05 11:00:00     751.138889              0.0
# 2011-04-05 12:00:00     930.277778              0.0
# 2011-04-05 13:00:00     739.388889              0.0
# 2011-04-05 14:00:00     535.777778              0.0

# %%
latitude = 0.336626
longitude = 32.565610

# %%
plt.figure(figsize=(10, 6))
df_kampala['GHI (W/m2)'].loc['2022'].plot()
plt.title('Global Horizontal Irradiance in Kampala')
plt.show()
