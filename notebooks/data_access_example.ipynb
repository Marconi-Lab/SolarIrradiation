# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
import sys
from pathlib import Path

src_path = (Path.cwd() / "../src/susse").resolve()
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %% [markdown]
# # Prerequisites
#
# Authenticate once on your machine:
# ```bash
# gcloud auth application-default login
# gcloud config set project solar-irradiation-estimation
# ```

# %% [markdown]
# # Access Solar Warehouse
#
# The Solar Warehouse contains all pre-downloaded data as well as the measured ground-irradiation (from Crossboundary and other sources). We can access it through the pre-constructed BigQueryClient(). In orer to

# %%
from src.susse.warehouse_ops.io import BigQueryClient, TableRefs, FeatureService
from datetime import date

bq = BigQueryClient()
tables = TableRefs()
svc = FeatureService(bq, tables)

# Training pairs for a short range
df_pairs = svc.build_training_pairs(
    start=date(2024, 2, 1), end=date(2024, 2, 15),
    locations=None,
    nasa_variables=["T2M", "CLRSKY_DNI"],
)
print(df_pairs.head())

# Inference features for one point/time
features = svc.build_inference_features(
    target_date=date(2024, 2, 15), lat=-1.38214, lon=29.671499,
    nasa_variables=["T2M"],
)
# print(features)
# Out:
# /home/jan/.pyenv/versions/.venv_irradiation/lib/python3.11/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#          date              location        lat        lon geohash5  \
# 0  2024-02-09  madagascar_location1 -25.053564  46.947956    m593k
# 1  2024-02-06  madagascar_location1 -25.053564  46.947956    m593k
# 2  2024-02-14  madagascar_location1 -25.053564  46.947956    m593k
# 3  2024-02-03  madagascar_location1 -25.053564  46.947956    m593k
# 4  2024-02-13  madagascar_location1 -25.053564  46.947956    m593k
#
#    y_ghi_kwh_m2_day  sat_ghi_cams_kwh_m2_day  sat_ghi_nasa_kwh_m2_day
# 0          6.031718                      NaN                      NaN
# 1          6.563118                      NaN                      NaN
# 2          4.846616                      NaN                      NaN
# ...
